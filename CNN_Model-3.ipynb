# %%
from __future__ import print_function
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.regularizers import l2
import numpy as np
import os
import matplotlib.pyplot as plt
plt.rcParams['axes.unicode_minus'] = False
plt.style.use('fivethirtyeight')
# %matplotlib inline

# Defining the parameters
batch_size = 32
num_classes = 10
epochs = 50

# %%
# Splitting the data between train and test
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
# plotting some random 10 images

class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

fig = plt.figure(figsize=(10,5))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(y_train[:]==i)[0]
    features_idx = x_train[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = (features_idx[img_num,::])
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
# Convert class vectors to binary class matrices.
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
# Building the CNN Model

model = Sequential()
model.add(Conv2D(64, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512,kernel_regularizer=l2(0.01)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
# compile (Hidden Output)
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalizing the input image
x_train /= 255
x_test /= 255

epochs=50

# Training the model
history = model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 380s 243ms/step - loss: 8.5380 - accuracy: 0.4200 - val_loss: 6.2758 - val_accuracy: 0.5361
# Epoch 2/50
# 1563/1563 [==============================] - 196s 125ms/step - loss: 4.9776 - accuracy: 0.5598 - val_loss: 3.8468 - val_accuracy: 0.5983
# Epoch 3/50
# 1563/1563 [==============================] - 220s 141ms/step - loss: 3.1070 - accuracy: 0.6347 - val_loss: 2.4620 - val_accuracy: 0.6775
# Epoch 4/50
# 1563/1563 [==============================] - 209s 134ms/step - loss: 2.0873 - accuracy: 0.6888 - val_loss: 1.7698 - val_accuracy: 0.6982
# Epoch 5/50
# 1563/1563 [==============================] - 214s 137ms/step - loss: 1.5367 - accuracy: 0.7192 - val_loss: 1.3373 - val_accuracy: 0.7381
# Epoch 6/50
# 1563/1563 [==============================] - 216s 138ms/step - loss: 1.2380 - accuracy: 0.7417 - val_loss: 1.1759 - val_accuracy: 0.7384
# Epoch 7/50
# 1563/1563 [==============================] - 201s 129ms/step - loss: 1.0644 - accuracy: 0.7604 - val_loss: 1.1427 - val_accuracy: 0.7254
# Epoch 8/50
# 1563/1563 [==============================] - 171s 110ms/step - loss: 0.9637 - accuracy: 0.7768 - val_loss: 0.9408 - val_accuracy: 0.7816
# Epoch 9/50
# 1563/1563 [==============================] - 156s 100ms/step - loss: 0.9012 - accuracy: 0.7876 - val_loss: 1.0343 - val_accuracy: 0.7448
# Epoch 10/50
# 1563/1563 [==============================] - 159s 102ms/step - loss: 0.8605 - accuracy: 0.7999 - val_loss: 0.9624 - val_accuracy: 0.7667
# Epoch 11/50
# 1563/1563 [==============================] - 160s 103ms/step - loss: 0.8308 - accuracy: 0.8106 - val_loss: 0.9641 - val_accuracy: 0.7745
# Epoch 12/50
# 1563/1563 [==============================] - 164s 105ms/step - loss: 0.8112 - accuracy: 0.8222 - val_loss: 0.8795 - val_accuracy: 0.8034
# Epoch 13/50
# 1563/1563 [==============================] - 142s 91ms/step - loss: 0.7931 - accuracy: 0.8289 - val_loss: 1.0633 - val_accuracy: 0.7466
# Epoch 14/50
# 1563/1563 [==============================] - 148s 95ms/step - loss: 0.7858 - accuracy: 0.8367 - val_loss: 0.9149 - val_accuracy: 0.7989
# Epoch 15/50
# 1563/1563 [==============================] - 143s 91ms/step - loss: 0.7722 - accuracy: 0.8478 - val_loss: 0.9744 - val_accuracy: 0.7872
# Epoch 16/50
# 1563/1563 [==============================] - 148s 95ms/step - loss: 0.7725 - accuracy: 0.8503 - val_loss: 0.9151 - val_accuracy: 0.8064
# Epoch 17/50
# 1563/1563 [==============================] - 136s 87ms/step - loss: 0.7756 - accuracy: 0.8560 - val_loss: 0.9519 - val_accuracy: 0.8028
# Epoch 18/50
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.7705 - accuracy: 0.8622 - val_loss: 0.9646 - val_accuracy: 0.8022
# Epoch 19/50
# 1563/1563 [==============================] - 133s 85ms/step - loss: 0.7662 - accuracy: 0.8683 - val_loss: 1.0127 - val_accuracy: 0.7966
# Epoch 20/50
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.7673 - accuracy: 0.8696 - val_loss: 1.0202 - val_accuracy: 0.7962
# Epoch 21/50
# 1563/1563 [==============================] - 127s 81ms/step - loss: 0.7662 - accuracy: 0.8736 - val_loss: 0.9804 - val_accuracy: 0.8118
# Epoch 22/50
# 1563/1563 [==============================] - 126s 80ms/step - loss: 0.7637 - accuracy: 0.8807 - val_loss: 0.9540 - val_accuracy: 0.8253
# Epoch 23/50
# 1563/1563 [==============================] - 117s 75ms/step - loss: 0.7611 - accuracy: 0.8817 - val_loss: 0.9660 - val_accuracy: 0.8217
# Epoch 24/50
# 1563/1563 [==============================] - 116s 74ms/step - loss: 0.7645 - accuracy: 0.8841 - val_loss: 1.0098 - val_accuracy: 0.8162
# Epoch 25/50
# 1563/1563 [==============================] - 119s 76ms/step - loss: 0.7598 - accuracy: 0.8891 - val_loss: 0.9690 - val_accuracy: 0.8243
# Epoch 26/50
# 1563/1563 [==============================] - 138s 88ms/step - loss: 0.7661 - accuracy: 0.8897 - val_loss: 1.0164 - val_accuracy: 0.8221
# Epoch 27/50
# 1563/1563 [==============================] - 122s 78ms/step - loss: 0.7593 - accuracy: 0.8931 - val_loss: 1.0091 - val_accuracy: 0.8224
# Epoch 28/50
# 1563/1563 [==============================] - 121s 77ms/step - loss: 0.7587 - accuracy: 0.8947 - val_loss: 1.0108 - val_accuracy: 0.8250
# Epoch 29/50
# 1563/1563 [==============================] - 120s 77ms/step - loss: 0.7617 - accuracy: 0.8977 - val_loss: 0.9947 - val_accuracy: 0.8325
# Epoch 30/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.7580 - accuracy: 0.8987 - val_loss: 1.0159 - val_accuracy: 0.8281
# Epoch 31/50
# 1563/1563 [==============================] - 148s 95ms/step - loss: 0.7516 - accuracy: 0.9027 - val_loss: 1.0393 - val_accuracy: 0.8224
# Epoch 32/50
# 1563/1563 [==============================] - 151s 96ms/step - loss: 0.7490 - accuracy: 0.9041 - val_loss: 1.0238 - val_accuracy: 0.8305
# Epoch 33/50
# 1563/1563 [==============================] - 156s 100ms/step - loss: 0.7550 - accuracy: 0.9034 - val_loss: 1.0041 - val_accuracy: 0.8327
# Epoch 34/50
# 1563/1563 [==============================] - 167s 107ms/step - loss: 0.7503 - accuracy: 0.9073 - val_loss: 1.2054 - val_accuracy: 0.7849
# Epoch 35/50
# 1563/1563 [==============================] - 160s 102ms/step - loss: 0.7435 - accuracy: 0.9082 - val_loss: 1.0476 - val_accuracy: 0.8321
# Epoch 36/50
# 1563/1563 [==============================] - 175s 112ms/step - loss: 0.7440 - accuracy: 0.9088 - val_loss: 1.0349 - val_accuracy: 0.8302
# Epoch 37/50
# 1563/1563 [==============================] - 168s 107ms/step - loss: 0.7413 - accuracy: 0.9108 - val_loss: 1.0238 - val_accuracy: 0.8335
# Epoch 38/50
# 1563/1563 [==============================] - 150s 96ms/step - loss: 0.7395 - accuracy: 0.9118 - val_loss: 1.0401 - val_accuracy: 0.8370
# Epoch 39/50
# 1563/1563 [==============================] - 150s 96ms/step - loss: 0.7418 - accuracy: 0.9117 - val_loss: 1.0263 - val_accuracy: 0.8339
# Epoch 40/50
# 1563/1563 [==============================] - 152s 97ms/step - loss: 0.7383 - accuracy: 0.9131 - val_loss: 1.0445 - val_accuracy: 0.8253
# Epoch 41/50
# 1563/1563 [==============================] - 146s 93ms/step - loss: 0.7371 - accuracy: 0.9135 - val_loss: 1.0892 - val_accuracy: 0.8186
# Epoch 42/50
# 1563/1563 [==============================] - 135s 86ms/step - loss: 0.7333 - accuracy: 0.9148 - val_loss: 1.0203 - val_accuracy: 0.8375
# Epoch 43/50
# 1563/1563 [==============================] - 138s 88ms/step - loss: 0.7207 - accuracy: 0.9176 - val_loss: 1.0129 - val_accuracy: 0.8365
# Epoch 44/50
# 1563/1563 [==============================] - 130s 83ms/step - loss: 0.7256 - accuracy: 0.9183 - val_loss: 1.0601 - val_accuracy: 0.8301
# Epoch 45/50
# 1563/1563 [==============================] - 129s 82ms/step - loss: 0.7255 - accuracy: 0.9162 - val_loss: 1.0567 - val_accuracy: 0.8320
# Epoch 46/50
# 1563/1563 [==============================] - 124s 79ms/step - loss: 0.7253 - accuracy: 0.9183 - val_loss: 1.0319 - val_accuracy: 0.8363
# Epoch 47/50
# 1563/1563 [==============================] - 184s 118ms/step - loss: 0.7158 - accuracy: 0.9230 - val_loss: 1.0445 - val_accuracy: 0.8370
# Epoch 48/50
# 1563/1563 [==============================] - 165s 105ms/step - loss: 0.7071 - accuracy: 0.9228 - val_loss: 1.0420 - val_accuracy: 0.8344
# Epoch 49/50
# 1563/1563 [==============================] - 128s 82ms/step - loss: 0.7132 - accuracy: 0.9205 - val_loss: 1.0857 - val_accuracy: 0.8245
# Epoch 50/50
# 1563/1563 [==============================] - 129s 82ms/step - loss: 0.7036 - accuracy: 0.9247 - val_loss: 1.0265 - val_accuracy: 0.8398

# %%
# Plotting the Model Accuracy & Model Loss vs Epochs (Hidden Input)
plt.figure(figsize=[20,8])

# summarize history for accuracy
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy', size=25, pad=20)
plt.ylabel('Accuracy', size=15)
plt.xlabel('Epoch', size=15)
plt.legend(['train', 'test'], loc='upper left')
# summarize history for loss

plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss', size=25, pad=20)
plt.ylabel('Loss', size=15)
plt.xlabel('Epoch', size=15)
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Checking the predictions! 
predictions = model.predict(x_test)

plt.figure(figsize=[10,10])

class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

plt.subplot(2,2,1)
n = 3
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.subplot(2,2,2)
n = 4
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.subplot(2,2,3)
n = 8
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.subplot(2,2,4)
n = 6
plt.imshow(x_test[n].reshape(32, 32, -1), cmap=plt.cm.binary)
plt.title("Predicted value: " + str(class_names[np.argmax(predictions[n], axis=0)]), size=20)
plt.grid(False)

plt.suptitle("Predictions of CIFAR-10 Data", size=30, color="#6166B3")

plt.show()
# Out:
# 313/313 [==============================] - 6s 19ms/step
